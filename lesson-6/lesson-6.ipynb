# %%
import os
import pandas as pd
from dotenv import load_dotenv

load_dotenv("../.env")

url = os.getenv("LOCAL_LESSON6_DS")

df = pd.read_csv(url)

print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = df.rename(columns = { 
    "PassengerId": "Идентификатор пассажира",
    "Survived": "Выжил",
    "Pclass": "Класс билета", 
    "Name": "Имя",
    "Sex": "Пол",
    "Age": "Возраст",
    "SibSp": "Количество братьев/сестер/супругов на борту",
    "Parch": "Количество родителей/детей на борту",
    "Ticket": "Номер билета",
    "Fare": "Стоимость билета",
    "Cabin": "Номер каюты",
    "Embarked": "Порт посадки"
})

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dtypes
# Out:
# Идентификатор пассажира                          int64
# Выжил                                            int64
# Класс билета                                     int64
# Имя                                             object
# Пол                                             object
# Возраст                                        float64
# Количество братьев/сестер/супругов на борту      int64
# Количество родителей/детей на борту              int64
# Номер билета                                    object
# Стоимость билета                               float64
# Номер каюты                                     object
# Порт посадки                                    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Идентификатор пассажира                      891 non-null    int64
#  1   Выжил                                        891 non-null    int64
#  2   Класс билета                                 891 non-null    int64
#  3   Имя                                          891 non-null    object
#  4   Пол                                          891 non-null    object
#  5   Возраст                                      714 non-null    float64
#  6   Количество братьев/сестер/супругов на борту  891 non-null    int64
#  7   Количество родителей/детей на борту          891 non-null    int64
#  8   Номер билета                                 891 non-null    object
# ...

# %%
df.describe()
# Out:
#        Идентификатор пассажира       Выжил  Класс билета     Возраст  \
# count               891.000000  891.000000    891.000000  714.000000
# mean                446.000000    0.383838      2.308642   29.699118
# std                 257.353842    0.486592      0.836071   14.526497
# min                   1.000000    0.000000      1.000000    0.420000
# 25%                 223.500000    0.000000      2.000000   20.125000
# 50%                 446.000000    0.000000      3.000000   28.000000
# 75%                 668.500000    1.000000      3.000000   38.000000
# max                 891.000000    1.000000      3.000000   80.000000
#
#        Количество братьев/сестер/супругов на борту  \
# count                                   891.000000
# mean                                      0.523008
# std                                       1.102743
# min                                       0.000000
# 25%                                       0.000000
# ...

# %%
df.drop(columns = ['Имя', 'Пол', 'Номер билета', 'Номер каюты', 'Порт посадки']).median()
# Out:
# Идентификатор пассажира                        446.0000
# Выжил                                            0.0000
# Класс билета                                     3.0000
# Возраст                                         28.0000
# Количество братьев/сестер/супругов на борту      0.0000
# Количество родителей/детей на борту              0.0000
# Стоимость билета                                14.4542
# dtype: float64

# %%
df.drop(columns = ['Имя', 'Пол', 'Номер билета', 'Номер каюты', 'Порт посадки']).mean()
# Out:
# Идентификатор пассажира                        446.000000
# Выжил                                            0.383838
# Класс билета                                     2.308642
# Возраст                                         29.699118
# Количество братьев/сестер/супругов на борту      0.523008
# Количество родителей/детей на борту              0.381594
# Стоимость билета                                32.204208
# dtype: float64

# %%
df.mode().fillna("")
# Out:
#      Идентификатор пассажира Выжил Класс билета  \
# 0                          1   0.0          3.0
# 1                          2
# 2                          3
# 3                          4
# 4                          5
# ..                       ...   ...          ...
# 886                      887
# 887                      888
# 888                      889
# 889                      890
# 890                      891
#
#                                        Имя   Пол Возраст  \
# 0                      Abbing, Mr. Anthony  male    24.0
# 1              Abbott, Mr. Rossmore Edward
# 2         Abbott, Mrs. Stanton (Rosa Hunt)
# 3                      Abelson, Mr. Samuel
# 4    Abelson, Mrs. Samuel (Hannah Wizosky)
# ..                                     ...   ...     ...
# 886                de Mulder, Mr. Theodore
# 887              de Pelsmaeker, Mr. Alfons
# 888              del Carlo, Mr. Sebastiano
# 889        van Billiard, Mr. Austin Blyler
# ...

# %%
df.drop(columns = ['Имя', 'Пол', 'Номер билета', 'Номер каюты', 'Порт посадки']).skew()
# Out:
# Идентификатор пассажира                        0.000000
# Выжил                                          0.478523
# Класс билета                                  -0.630548
# Возраст                                        0.389108
# Количество братьев/сестер/супругов на борту    3.695352
# Количество родителей/детей на борту            2.749117
# Стоимость билета                               4.787317
# dtype: float64

# %%
df.drop(columns = ['Имя', 'Пол', 'Номер билета', 'Номер каюты', 'Порт посадки']).corr().replace(to_replace=1, value='')
# corr Стоимость билета x Выжил; Стоимость билета x Класс билета; Класс билета x Возраст;
# Количество родителей/детей на борту x Количество братьев/сестер/супругов на борту;
# Out:
#                                             Идентификатор пассажира     Выжил  \
# Идентификатор пассажира                                             -0.005007
# Выжил                                                     -0.005007
# Класс билета                                              -0.035144 -0.338481
# Возраст                                                    0.036847 -0.077221
# Количество братьев/сестер/супругов на борту               -0.057527 -0.035322
# Количество родителей/детей на борту                       -0.001652  0.081629
# Стоимость билета                                           0.012658  0.257307
#
#                                             Класс билета   Возраст  \
# Идентификатор пассажира                        -0.035144  0.036847
# Выжил                                          -0.338481 -0.077221
# Класс билета                                             -0.369226
# Возраст                                        -0.369226
# ...

# %%
df.drop(columns = ['Имя', 'Пол', 'Номер билета', 'Номер каюты', 'Порт посадки']).corr(method='spearman').replace(to_replace=1, value='')
# Out:
#                                             Идентификатор пассажира     Выжил  \
# Идентификатор пассажира                                             -0.005007
# Выжил                                                     -0.005007
# Класс билета                                              -0.034091 -0.339668
# Возраст                                                     0.04101 -0.052565
# Количество братьев/сестер/супругов на борту               -0.061161  0.088879
# Количество родителей/детей на борту                        0.001235  0.138266
# Стоимость билета                                          -0.013975  0.323736
#
#                                             Класс билета   Возраст  \
# Идентификатор пассажира                        -0.034091   0.04101
# Выжил                                          -0.339668 -0.052565
# Класс билета                                             -0.361666
# Возраст                                        -0.361666
# ...

# %%
df.drop_duplicates(subset='Порт посадки')
# Out:
#     Идентификатор пассажира  Выжил  Класс билета  \
# 0                         1      0             3
# 1                         2      1             1
# 5                         6      0             3
# 61                       62      1             1
#
#                                                   Имя     Пол  Возраст  \
# 0                             Braund, Mr. Owen Harris    male     22.0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female     38.0
# 5                                    Moran, Mr. James    male      NaN
# 61                                Icard, Miss. Amelie  female     38.0
#
#     Количество братьев/сестер/супругов на борту  \
# 0                                             1
# 1                                             1
# 5                                             0
# 61                                            0
#
#     Количество родителей/детей на борту Номер билета  Стоимость билета  \
# ...

# %%
df.drop(columns = ['Имя', 'Пол', 'Номер билета', 'Номер каюты', 'Порт посадки']).boxplot(figsize=(15,6), rot=90)
# corr Стоимость билета x Выжил; Стоимость билета x Класс билета; Класс билета x Возраст;
# Количество родителей/детей на борту x Количество братьев/сестер/супругов на борту;
# Проверить: Пол; стоимость билета на null, NaN 350 билетов за 0; Возраст;
# Out:
# <Axes: >

# %%
df['Стоимость билета'].value_counts()
# Out:
# Стоимость билета
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 13.8583     1
# 50.4958     1
# 5.0000      1
# 9.8458      1
# 10.5167     1
# Name: count, Length: 248, dtype: int64

# %%
import matplotlib.pyplot as plt

# # df.plot.scatter(x = 'Класс билета', y = 'Возраст')

# plt.scatter(df['Класс билета'], df['Возраст'])

# plt.show()

df.plot.scatter(x = 'Класс билета', y = 'Возраст')

plt.show()

# %%
df.dtypes
# Out:
# Идентификатор пассажира                          int64
# Выжил                                            int64
# Класс билета                                     int64
# Имя                                             object
# Пол                                             object
# Возраст                                        float64
# Количество братьев/сестер/супругов на борту      int64
# Количество родителей/детей на борту              int64
# Номер билета                                    object
# Стоимость билета                               float64
# Номер каюты                                     object
# Порт посадки                                    object
# dtype: object

# %%
# SibSp + Parch - точно размер семьи
# "Survived": "Выжил", "Name": "Имя", "Sex": "Пол", "Age": "Возраст" - индивидуальные характеристики
# + "Pclass": "Класс билета" и "Fare": "Стоимость билета" - социальный статус, тоже индивидуальная х-ка

# %%
df.sample(n=10)
# Out:
#      Идентификатор пассажира  Выжил  Класс билета  \
# 608                      609      1             2
# 735                      736      0             3
# 469                      470      1             3
# 530                      531      1             2
# 796                      797      1             1
# 242                      243      0             2
# 591                      592      1             1
# 447                      448      1             1
# 878                      879      0             3
# 449                      450      1             1
#
#                                                    Имя     Пол  Возраст  \
# 608  Laroche, Mrs. Joseph (Juliette Marie Louise La...  female    22.00
# 735                               Williams, Mr. Leslie    male    28.50
# 469                      Baclini, Miss. Helene Barbara  female     0.75
# 530                           Quick, Miss. Phyllis May  female     2.00
# ...

# %%
df.query('`Количество родителей/детей на борту` > 0').plot.hist(column=['Выжил'], by=['Пол'])

plt.show()

# %%
df.query('`Пол` == "male"').plot.hist(column=['Выжил'], by=['Класс билета'])

plt.show()

# %%
df.query('`Пол` == "female"').plot.hist(column=['Выжил'], by=['Класс билета'])

plt.show()

# %%
df.query('`Пол` == "female"').plot.hist(column=['Выжил'], by=['Порт посадки'])

plt.show()

# %%
df.query('`Пол` == "male"').plot.hist(column=['Выжил'], by=['Порт посадки'])

plt.show()

# %%
df.query('`Имя`.str.contains("Fortune")', engine='python')
# Out:
#      Идентификатор пассажира  Выжил  Класс билета  \
# 27                        28      0             1
# 88                        89      1             1
# 341                      342      1             1
# 438                      439      0             1
#
#                                 Имя     Пол  Возраст  \
# 27   Fortune, Mr. Charles Alexander    male     19.0
# 88       Fortune, Miss. Mabel Helen  female     23.0
# 341  Fortune, Miss. Alice Elizabeth  female     24.0
# 438               Fortune, Mr. Mark    male     64.0
#
#      Количество братьев/сестер/супругов на борту  \
# 27                                             3
# 88                                             3
# 341                                            3
# 438                                            1
#
#      Количество родителей/детей на борту Номер билета  Стоимость билета  \
# 27                                     2        19950             263.0
# ...

# %%
df.query('`Номер билета`.str.contains("19950")', engine='python')
# Out:
#      Идентификатор пассажира  Выжил  Класс билета  \
# 27                        28      0             1
# 88                        89      1             1
# 341                      342      1             1
# 438                      439      0             1
#
#                                 Имя     Пол  Возраст  \
# 27   Fortune, Mr. Charles Alexander    male     19.0
# 88       Fortune, Miss. Mabel Helen  female     23.0
# 341  Fortune, Miss. Alice Elizabeth  female     24.0
# 438               Fortune, Mr. Mark    male     64.0
#
#      Количество братьев/сестер/супругов на борту  \
# 27                                             3
# 88                                             3
# 341                                            3
# 438                                            1
#
#      Количество родителей/детей на борту Номер билета  Стоимость билета  \
# 27                                     2        19950             263.0
# ...

# %%
df.fillna("").query('`Номер каюты`.str.contains("C23 C25 C27")', engine='python')
# Out:
#      Идентификатор пассажира  Выжил  Класс билета  \
# 27                        28      0             1
# 88                        89      1             1
# 341                      342      1             1
# 438                      439      0             1
#
#                                 Имя     Пол Возраст  \
# 27   Fortune, Mr. Charles Alexander    male    19.0
# 88       Fortune, Miss. Mabel Helen  female    23.0
# 341  Fortune, Miss. Alice Elizabeth  female    24.0
# 438               Fortune, Mr. Mark    male    64.0
#
#      Количество братьев/сестер/супругов на борту  \
# 27                                             3
# 88                                             3
# 341                                            3
# 438                                            1
#
#      Количество родителей/детей на борту Номер билета  Стоимость билета  \
# 27                                     2        19950             263.0
# ...

# %%
df.query('`Имя`.str.contains("Quick")', engine='python')
# Out:
#      Идентификатор пассажира  Выжил  Класс билета  \
# 506                      507      1             2
# 530                      531      1             2
#
#                                                Имя     Пол  Возраст  \
# 506  Quick, Mrs. Frederick Charles (Jane Richards)  female     33.0
# 530                       Quick, Miss. Phyllis May  female      2.0
#
#      Количество братьев/сестер/супругов на борту  \
# 506                                            0
# 530                                            1
#
#      Количество родителей/детей на борту Номер билета  Стоимость билета  \
# 506                                    2        26360              26.0
# 530                                    1        26360              26.0
#
#     Номер каюты Порт посадки
# 506         NaN            S
# 530         NaN            S

# %%
df.query('`Количество братьев/сестер/супругов на борту`>4', engine='python')
# Out:
#      Идентификатор пассажира  Выжил  Класс билета  \
# 59                        60      0             3
# 71                        72      0             3
# 159                      160      0             3
# 180                      181      0             3
# 201                      202      0             3
# 324                      325      0             3
# 386                      387      0             3
# 480                      481      0             3
# 683                      684      0             3
# 792                      793      0             3
# 846                      847      0             3
# 863                      864      0             3
#
#                                     Имя     Пол  Возраст  \
# 59   Goodwin, Master. William Frederick    male     11.0
# 71           Goodwin, Miss. Lillian Amy  female     16.0
# 159          Sage, Master. Thomas Henry    male      NaN
# 180        Sage, Miss. Constance Gladys  female      NaN
# ...

# %%
df.query('`Имя`.str.contains("Sage,")', engine='python')
# Out:
#      Идентификатор пассажира  Выжил  Класс билета  \
# 159                      160      0             3
# 180                      181      0             3
# 201                      202      0             3
# 324                      325      0             3
# 792                      793      0             3
# 846                      847      0             3
# 863                      864      0             3
#
#                                    Имя     Пол  Возраст  \
# 159         Sage, Master. Thomas Henry    male      NaN
# 180       Sage, Miss. Constance Gladys  female      NaN
# 201                Sage, Mr. Frederick    male      NaN
# 324           Sage, Mr. George John Jr    male      NaN
# 792            Sage, Miss. Stella Anna  female      NaN
# 846           Sage, Mr. Douglas Bullen    male      NaN
# 863  Sage, Miss. Dorothy Edith "Dolly"  female      NaN
#
#      Количество братьев/сестер/супругов на борту  \
# 159                                            8
# ...

# %%
df.query('`Номер билета`.str.contains("CA. 2343")', engine='python')
# Out:
#      Идентификатор пассажира  Выжил  Класс билета  \
# 159                      160      0             3
# 180                      181      0             3
# 201                      202      0             3
# 324                      325      0             3
# 792                      793      0             3
# 846                      847      0             3
# 863                      864      0             3
#
#                                    Имя     Пол  Возраст  \
# 159         Sage, Master. Thomas Henry    male      NaN
# 180       Sage, Miss. Constance Gladys  female      NaN
# 201                Sage, Mr. Frederick    male      NaN
# 324           Sage, Mr. George John Jr    male      NaN
# 792            Sage, Miss. Stella Anna  female      NaN
# 846           Sage, Mr. Douglas Bullen    male      NaN
# 863  Sage, Miss. Dorothy Edith "Dolly"  female      NaN
#
#      Количество братьев/сестер/супругов на борту  \
# 159                                            8
# ...

# %%
df.query('`Пол` == "male"').plot.hist(column=['Выжил'], by=['Класс билета'])

plt.show()

# %%
df.query('`Возраст` <= 12').plot.hist(column=['Выжил'], by=['Пол'])

plt.show()

# %%
df.query('`Возраст` <= 12 & `Класс билета` == 1')
# Out:
#      Идентификатор пассажира  Выжил  Класс билета  \
# 297                      298      0             1
# 305                      306      1             1
# 445                      446      1             1
# 802                      803      1             1
#
#                                      Имя     Пол  Возраст  \
# 297         Allison, Miss. Helen Loraine  female     2.00
# 305       Allison, Master. Hudson Trevor    male     0.92
# 445            Dodge, Master. Washington    male     4.00
# 802  Carter, Master. William Thornton II    male    11.00
#
#      Количество братьев/сестер/супругов на борту  \
# 297                                            1
# 305                                            1
# 445                                            0
# 802                                            1
#
#      Количество родителей/детей на борту Номер билета  Стоимость билета  \
# 297                                    2       113781          151.5500
# ...

# %%
df.query('`Возраст` <= 12 & `Класс билета` == 2')
# Out:
#      Идентификатор пассажира  Выжил  Класс билета  \
# 43                        44      1             2
# 58                        59      1             2
# 78                        79      1             2
# 183                      184      1             2
# 193                      194      1             2
# 237                      238      1             2
# 340                      341      1             2
# 407                      408      1             2
# 530                      531      1             2
# 535                      536      1             2
# 549                      550      1             2
# 618                      619      1             2
# 720                      721      1             2
# 750                      751      1             2
# 755                      756      1             2
# 827                      828      1             2
# 831                      832      1             2
#
# ...

# %%
df[df['Возраст'] <= 18]['Выжил'].sum()/df[df['Возраст'] <= 18]['Выжил'].count()
# Out:
# np.float64(0.5035971223021583)

# %%
df[(df['Возраст'] <= 18)& (df['Класс билета'] == 1)]['Выжил'].sum()/df[(df['Возраст'] <= 18) & (df['Класс билета'] == 1)]['Выжил'].count()

# Дети элиты выживали почти в 90% случаев
# Out:
# np.float64(0.875)

# %%
df['Класс билета'].nunique()
# Out:
# 3
